# %% [markdown]
# <a href="https://colab.research.google.com/github/itssadia/OpenCv/blob/main/face_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d88f08f2-b47f-41e7-a2ca-7ce9bbc0a342" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d88f08f2-b47f-41e7-a2ca-7ce9bbc0a342">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving big-bang-theory.jpg to big-bang-theory.jpg

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img_raw = cv2.imread('big-bang-theory.jpg')

# %%
plt.imshow(img_raw)

# %%
img = cv2.cvtColor(img_raw, cv2.COLOR_BGR2GRAY)
# Displaying the grayscale image
plt.imshow(img, cmap='gray')

# %%
def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
haar_cascade_face = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
faces_rects = haar_cascade_face.detectMultiScale(img, scaleFactor = 1.25, minNeighbors = 5);

# Let us print the no. of faces found
print('Faces found: ', len(faces_rects))
# Out:
# Faces found:  4

# %%
for (x,y,w,h) in faces_rects:
     cv2.rectangle(img_raw, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
#convert image to RGB and show image

plt.imshow(convertToRGB(img_raw))
